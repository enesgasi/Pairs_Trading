# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('sample_data.csv')

# %%
df
# Out:
#            var1     pmean  pvariance  pskewness     pkurtosis    pm  \
# 0      0.263052  0.964606   0.005870   0.000102  8.915095e-05  0.19
# 1      0.287508  0.929714   0.004527  -0.000038  3.720217e-05  0.03
# 2     -0.000000  1.011257   0.011259   0.001121  3.837712e-04  0.12
# 3      0.279096  0.955686   0.003988   0.000219  4.637987e-05  0.10
# 4      0.164670  0.908824   0.007617   0.000271  1.091615e-04  0.13
# ...         ...       ...        ...        ...           ...   ...
# 18577  0.087630  0.964750   0.000433   0.000009  6.352307e-07  0.01
# 18578  0.260597  0.864535   0.006258   0.000379  7.951991e-05  0.06
# 18579  0.110143  0.949998   0.000645   0.000004  9.436218e-07  0.01
# 18580  0.256919  0.906588   0.003858  -0.000033  2.351460e-05  0.06
# 18581  0.068767  1.014019   0.001345   0.000014  3.686108e-06  0.09
#
#           profit    price1    price2  p1  p2   t     corr1
# 0     -13.703410  0.740949  0.965383   1   2   1  0.352820
# 1     -17.684189  0.824347  0.816319   1   2   2  0.946411
# 2      25.592426  1.345471  1.121591   1   2   3  0.686128
# 3     -17.522108  0.832380  0.800319   1   2   4  0.712025
# 4      -2.111860  0.939418  0.982063   1   2   5  0.663702
# ...          ...       ...       ...  ..  ..  ..       ...
# 18577  -5.339546  0.971629  0.919907  49  50  17  0.852947
# 18578 -13.047666  0.796207  0.939138  49  50  18  0.891821
# 18579  -6.836501  0.938674  0.920849  49  50  20  0.780273
# 18580 -15.475427  0.863079  0.821464  49  50  22  0.942994
# 18581  -0.843232  1.013774  0.957213  49  50  23  0.828066
#
# [18582 rows x 13 columns]

# %%
plt.rcParams["figure.figsize"] = [20, 5]
plt.rcParams["figure.autolayout"] = True

price1 = df['price1'].head(100)
price2 = df['price2'].head(100)

plt.plot(price1, color='r', label='Price 1') 
plt.plot(price2, color='g', label='Price 2') 

plt.legend()
plt.show()

# %%
plt.rcParams["figure.figsize"] = [20, 5]
plt.rcParams["figure.autolayout"] = True
profit = df['profit']

plt.plot(profit)
